# %%
-!pip install pandas
# !pip install numpy
# !pip install matplotlib
# !pip install seaborn

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/content/Copy of Athletes.csv')

# %%
df.head(10)
# Out:
#                 Name                       NOC           Discipline
# 0    AALERUD Katrine                    Norway         Cycling Road
# 1        ABAD Nestor                     Spain  Artistic Gymnastics
# 2  ABAGNALE Giovanni                     Italy               Rowing
# 3     ABALDE Alberto                     Spain           Basketball
# 4      ABALDE Tamara                     Spain           Basketball
# 5          ABALO Luc                    France             Handball
# 6       ABAROA Cesar                     Chile               Rowing
# 7      ABASS Abobakr                     Sudan             Swimming
# 8   ABBASALI Hamideh  Islamic Republic of Iran               Karate
# 9      ABBASOV Islam                Azerbaijan            Wrestling

# %%
df.columns
# Out:
# Index(['Name', 'NOC', 'Discipline'], dtype='object')

# %%
df.isnull().sum()
# Out:
# Name          0
# NOC           0
# Discipline    0
# dtype: int64

# %%
df = df.fillna(0)

# %%
df.isnull().sum()
# Out:
# Name          0
# NOC           0
# Discipline    0
# dtype: int64

# %%
df.head(10)
# Out:
#                 Name                       NOC           Discipline
# 0    AALERUD Katrine                    Norway         Cycling Road
# 1        ABAD Nestor                     Spain  Artistic Gymnastics
# 2  ABAGNALE Giovanni                     Italy               Rowing
# 3     ABALDE Alberto                     Spain           Basketball
# 4      ABALDE Tamara                     Spain           Basketball
# 5          ABALO Luc                    France             Handball
# 6       ABAROA Cesar                     Chile               Rowing
# 7      ABASS Abobakr                     Sudan             Swimming
# 8   ABBASALI Hamideh  Islamic Republic of Iran               Karate
# 9      ABBASOV Islam                Azerbaijan            Wrestling

# %%
df.shape
# Out:
# (11085, 3)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11085 entries, 0 to 11084
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Name        11085 non-null  object
#  1   NOC         11085 non-null  object
#  2   Discipline  11085 non-null  object
# dtypes: object(3)
# memory usage: 259.9+ KB

# %%
nation=df['NOC']
nation
# Out:
# 0         Norway
# 1          Spain
# 2          Italy
# 3          Spain
# 4          Spain
#           ...
# 11080    Germany
# 11081     Poland
# 11082        ROC
# 11083        ROC
# 11084     Poland
# Name: NOC, Length: 11085, dtype: object

# %%
m=df.groupby(['NOC']).size()
m
# Out:
# NOC
# Afghanistan                 5
# Albania                     8
# Algeria                    41
# American Samoa              5
# Andorra                     2
#                            ..
# Virgin Islands, British     3
# Virgin Islands, US          4
# Yemen                       3
# Zambia                     29
# Zimbabwe                    5
# Length: 206, dtype: int64

# %%
df.head(20)
# Out:
#                        Name                       NOC           Discipline
# 0           AALERUD Katrine                    Norway         Cycling Road
# 1               ABAD Nestor                     Spain  Artistic Gymnastics
# 2         ABAGNALE Giovanni                     Italy               Rowing
# 3            ABALDE Alberto                     Spain           Basketball
# 4             ABALDE Tamara                     Spain           Basketball
# 5                 ABALO Luc                    France             Handball
# 6              ABAROA Cesar                     Chile               Rowing
# 7             ABASS Abobakr                     Sudan             Swimming
# 8          ABBASALI Hamideh  Islamic Republic of Iran               Karate
# 9             ABBASOV Islam                Azerbaijan            Wrestling
# 10             ABBINGH Lois               Netherlands             Handball
# ...

# %%
data = df['Discipline'].head(15)
d1 = df['NOC'].head(15)
plt.figure(figsize=(22, 10))
plt.bar(data, d1, width=0.2)
plt.xlabel('Discipline')
plt.ylabel('Number of Athletes')
plt.title('Athletes per Discipline')
plt.show()

# %%
data = df['Discipline'].head(13)
d1=df['NOC'].head(13)
colors = np.array(["red","green","blue","yellow","pink","black","orange","purple","beige","brown","gray","cyan","magenta"])
plt.figure(figsize=(20, 10))
plt.scatter(data,d1,c=colors)
plt.xlabel('Discipline')
plt.ylabel('NOC')
plt.title("Discipline VS  NOC" )
plt.show()

# %% [markdown]
# **MEDAL TALLY OF TOKYO OLYMPICS  2021**

# %%
df = pd.read_csv('/content/Copy of Medals.csv')

# %%
df.head(20)
# Out:
#     Rank                    Team/NOC  Gold  Silver  Bronze  Total  \
# 0      1    United States of America    39      41      33    113
# 1      2  People's Republic of China    38      32      18     88
# 2      3                       Japan    27      14      17     58
# 3      4               Great Britain    22      21      22     65
# 4      5                         ROC    20      28      23     71
# 5      6                   Australia    17       7      22     46
# 6      7                 Netherlands    10      12      14     36
# 7      8                      France    10      12      11     33
# 8      9                     Germany    10      11      16     37
# 9     10                       Italy    10      10      20     40
# 10    11                      Canada     7       6      11     24
# 11    12                      Brazil     7       6       8     21
# 12    13                 New Zealand     7       6       7     20
# ...

# %%
df.columns
# Out:
# Index(['Rank', 'Team/NOC', 'Gold', 'Silver', 'Bronze', 'Total',
#        'Rank by Total'],
#       dtype='object')

# %%
df.isnull().sum()
# Out:
# Rank             0
# Team/NOC         0
# Gold             0
# Silver           0
# Bronze           0
# Total            0
# Rank by Total    0
# dtype: int64

# %%
df = df.fillna(0)

# %%
df.isnull().sum()
# Out:
# Rank             0
# Team/NOC         0
# Gold             0
# Silver           0
# Bronze           0
# Total            0
# Rank by Total    0
# dtype: int64

# %%
df.head(20)
# Out:
#     Rank                    Team/NOC  Gold  Silver  Bronze  Total  \
# 0      1    United States of America    39      41      33    113
# 1      2  People's Republic of China    38      32      18     88
# 2      3                       Japan    27      14      17     58
# 3      4               Great Britain    22      21      22     65
# 4      5                         ROC    20      28      23     71
# 5      6                   Australia    17       7      22     46
# 6      7                 Netherlands    10      12      14     36
# 7      8                      France    10      12      11     33
# 8      9                     Germany    10      11      16     37
# 9     10                       Italy    10      10      20     40
# 10    11                      Canada     7       6      11     24
# 11    12                      Brazil     7       6       8     21
# 12    13                 New Zealand     7       6       7     20
# ...

# %%
df.shape
# Out:
# (93, 7)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 93 entries, 0 to 92
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Rank           93 non-null     int64
#  1   Team/NOC       93 non-null     object
#  2   Gold           93 non-null     int64
#  3   Silver         93 non-null     int64
#  4   Bronze         93 non-null     int64
#  5   Total          93 non-null     int64
#  6   Rank by Total  93 non-null     int64
# dtypes: int64(6), object(1)
# memory usage: 5.2+ KB

# %%
nation=df['Team/NOC']
nation
# Out:
# 0       United States of America
# 1     People's Republic of China
# 2                          Japan
# 3                  Great Britain
# 4                            ROC
#                  ...
# 88                         Ghana
# 89                       Grenada
# 90                        Kuwait
# 91           Republic of Moldova
# 92          Syrian Arab Republic
# Name: Team/NOC, Length: 93, dtype: object

# %%
df_sorted_gold=df.sort_values(by='Gold',ascending=False)
df_sorted_gold
# Out:
#     Rank                    Team/NOC  Gold  Silver  Bronze  Total  \
# 0      1    United States of America    39      41      33    113
# 1      2  People's Republic of China    38      32      18     88
# 2      3                       Japan    27      14      17     58
# 3      4               Great Britain    22      21      22     65
# 4      5                         ROC    20      28      23     71
# ..   ...                         ...   ...     ...     ...    ...
# 68    69                     Armenia     0       2       2      4
# 67    68          Dominican Republic     0       3       2      5
# 66    67                  Azerbaijan     0       3       4      7
# 65    66                    Colombia     0       4       1      5
# 92    86        Syrian Arab Republic     0       0       1      1
#
#     Rank by Total
# 0               1
# 1               2
# 2               5
# 3               4
# 4               3
# ..            ...
# 68             47
# ...

# %%
df_sorted_silver=df.sort_values(by='Silver',ascending=False)
df_sorted_silver
# Out:
#     Rank                    Team/NOC  Gold  Silver  Bronze  Total  \
# 0      1    United States of America    39      41      33    113
# 1      2  People's Republic of China    38      32      18     88
# 4      5                         ROC    20      28      23     71
# 3      4               Great Britain    22      21      22     65
# 2      3                       Japan    27      14      17     58
# ..   ...                         ...   ...     ...     ...    ...
# 41    42                     Bahamas     2       0       0      2
# 40    41                       Qatar     2       0       1      3
# 39    39                      Israel     2       0       2      4
# 38    39                     Ireland     2       0       2      4
# 92    86        Syrian Arab Republic     0       0       1      1
#
#     Rank by Total
# 0               1
# 1               2
# 4               3
# 3               4
# 2               5
# ..            ...
# 41             66
# ...

# %%
df_sorted_bronze=df.sort_values(by='Bronze',ascending=False)
df_sorted_bronze
# Out:
#     Rank                  Team/NOC  Gold  Silver  Bronze  Total  Rank by Total
# 0      1  United States of America    39      41      33    113              1
# 4      5                       ROC    20      28      23     71              3
# 3      4             Great Britain    22      21      22     65              4
# 5      6                 Australia    17       7      22     46              6
# 9     10                     Italy    10      10      20     40              7
# ..   ...                       ...   ...     ...     ...    ...            ...
# 76    77                   Bahrain     0       1       0      1             77
# 51    52              South Africa     1       2       0      3             60
# 57    58                   Tunisia     1       1       0      2             66
# 62    63                   Bermuda     1       0       0      1             77
# 46    46                 Venezuela     1       3       0      4             47
#
# [93 rows x 7 columns]

# %%
df_sorted.head(20)
# Out:
#     Rank                    Team/NOC  Gold  Silver  Bronze  Total  \
# 0      1    United States of America    39      41      33    113
# 1      2  People's Republic of China    38      32      18     88
# 2      3                       Japan    27      14      17     58
# 3      4               Great Britain    22      21      22     65
# 4      5                         ROC    20      28      23     71
# 5      6                   Australia    17       7      22     46
# 6      7                 Netherlands    10      12      14     36
# 7      8                      France    10      12      11     33
# 8      9                     Germany    10      11      16     37
# 9     10                       Italy    10      10      20     40
# 12    13                 New Zealand     7       6       7     20
# 13    14                        Cuba     7       3       5     15
# 11    12                      Brazil     7       6       8     21
# ...

# %%
data = df_sorted_gold['Gold'].head(15)
d1=df_sorted['Team/NOC'].head(15)
plt.figure(figsize=(10, 10))
plt.pie(data,labels=d1, autopct='%1.1f%%', startangle=120)
plt.title("NATION VS GOLD MEDALS" )
plt.legend()
plt.show()

# %%
sns.histplot(data=df, x='Gold')
plt.show()

# %%
plt.figure(figsize=(20, 10))
sns.barplot(x='Gold',y='Rank',data=df)
plt.show()
